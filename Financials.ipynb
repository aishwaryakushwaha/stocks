# %%
import pandas as pd
import requests

# %%
base_url="https://financialmodelingprep.com/stable/income-statement"
data_type="search-symbol"
API_key="fbI5QjDLjJNXRkvWFrM7z9i7jjd83SYK"
search_item= "TSLA"

# %%
url= f"{base_url}?symbol={search_item}&apikey={API_key}"

# %%
url
# Out:
# 'https://financialmodelingprep.com/stable/income-statement?symbol=TSLA&apikey=fbI5QjDLjJNXRkvWFrM7z9i7jjd83SYK'

# %%
response= requests.get(url)

# %%
data= response.json()

# %%
data
# Out:
# [{'date': '2024-12-31',
#   'symbol': 'TSLA',
#   'reportedCurrency': 'USD',
#   'cik': '0001318605',
#   'filingDate': '2025-01-30',
#   'acceptedDate': '2025-01-29 20:42:33',
#   'fiscalYear': '2024',
#   'period': 'FY',
#   'revenue': 97690000000,
#   'costOfRevenue': 80240000000,
#   'grossProfit': 17450000000,
#   'researchAndDevelopmentExpenses': 4540000000,
#   'generalAndAdministrativeExpenses': 5150000000,
#   'sellingAndMarketingExpenses': 0,
#   'sellingGeneralAndAdministrativeExpenses': 5150000000,
#   'otherExpenses': 684000000,
#   'operatingExpenses': 10374000000,
#   'costAndExpenses': 90614000000,
#   'netInterestIncome': 1219000000,
#   'interestIncome': 1569000000,
#   'interestExpense': 350000000,
#   'depreciationAndAmortization': 5368000000,
#   'ebitda': 14708000000,
#   'ebit': 9340000000,
#   'nonOperatingIncomeExcludingInterest': -2264000000,
#   'operatingIncome': 7076000000,
#   'totalOtherIncomeExpensesNet': 1914000000,
#   'incomeBeforeTax': 8990000000,
# ...

# %%
len(data)
# Out:
# 5

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#          date symbol reportedCurrency         cik  filingDate  \
# 0  2024-12-31   TSLA              USD  0001318605  2025-01-30
# 1  2023-12-31   TSLA              USD  0001318605  2024-01-29
# 2  2022-12-31   TSLA              USD  0001318605  2023-01-31
# 3  2021-12-31   TSLA              USD  0001318605  2022-02-07
# 4  2020-12-31   TSLA              USD  0001318605  2021-02-08
#
#           acceptedDate fiscalYear period      revenue  costOfRevenue  ...  \
# 0  2025-01-29 20:42:33       2024     FY  97690000000    80240000000  ...
# 1  2024-01-26 21:00:20       2023     FY  96773000000    79113000000  ...
# 2  2023-01-30 21:29:15       2022     FY  81462000000    60609000000  ...
# 3  2022-02-04 20:11:27       2021     FY  53823000000    40217000000  ...
# 4  2021-02-08 07:27:23       2020     FY  31536000000    24906000000  ...
#
#    netIncomeFromContinuingOperations  netIncomeFromDiscontinuedOperations  \
# ...

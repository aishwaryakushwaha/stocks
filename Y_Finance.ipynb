# %%
import pandas as pd
import yfinance as yf

# %%
SBIN =yf.Ticker("SBIN.NS")

# %%
SBIN.info
# Out:
# {'address1': 'State Bank Bhavan, Corporate Centre',
#  'address2': 'Madame Cama Road Nariman Point',
#  'city': 'Mumbai',
#  'zip': '400021',
#  'country': 'India',
#  'phone': '91 22 2274 0840',
#  'website': 'https://sbi.bank.in',
#  'industry': 'Banks - Regional',
#  'industryKey': 'banks-regional',
#  'industryDisp': 'Banks - Regional',
#  'sector': 'Financial Services',
#  'sectorKey': 'financial-services',
#  'sectorDisp': 'Financial Services',
# ...

# %%
REL =yf.Ticker("RELIANCE.NS","SBIN.NS")
# Out:
# ---------------------------------------------------------------------------
# YFDataException                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17352/158241358.py in <module>
# ----> 1 REL =yf.Ticker("RELIANCE.NS","SBIN.NS")
#
# ~\anaconda3\lib\site-packages\yfinance\ticker.py in __init__(self, ticker, session, proxy)
#      37             warnings.warn("Set proxy via new config function: yf.set_config(proxy=proxy)", DeprecationWarning, stacklevel=2)
#      38             self._data._set_proxy(proxy)
# ---> 39         super(Ticker, self).__init__(ticker, session=session)
#      40         self._expirations = {}
#      41         self._underlying  = {}
#
# ~\anaconda3\lib\site-packages\yfinance\base.py in __init__(self, ticker, session, proxy)
#      98             raise ValueError("Empty ticker name")
#      99
# --> 100         self._data: YfData = YfData(session=session)
#     101         if proxy is not _SENTINEL_:
# ...

# %%
REL.info
# Out:
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: RELIANCE.NS SBIN.NS"}}}
# {'trailingPegRatio': None}

# %%
from indstocks import stocks
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17352/1466642352.py in <module>
# ----> 1 from indstocks import stocks
#
# ModuleNotFoundError: No module named 'indstocks'
